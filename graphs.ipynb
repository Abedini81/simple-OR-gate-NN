# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("C:/Users/abedi/OneDrive/Desktop/Simple NN/Touch Gates/loss_values_gates.csv", header=None)
df.head()
# Out:
#           0
# 0  0.000000
# 1  0.168799
# 2  0.167405
# 3  0.166064
# 4  0.164772

# %%
df.columns = ["Loss function"]

# %%
df.head()
# Out:
#    Loss function
# 0       0.000000
# 1       0.168799
# 2       0.167405
# 3       0.166064
# 4       0.164772

# %%
len(df["Loss function"])
# Out:
# 5001

# %%
X = [x for x in range(len(df))]
y = df['Loss function'].sort_values(ascending=False)

# %%
y.head()
# Out:
# 1    0.168799
# 2    0.167405
# 3    0.166064
# 4    0.164772
# 5    0.163527
# Name: Loss function, dtype: float64

# %%
plt.figure(figsize=(10,8))
plt.scatter(x=X, y=y, c=df['Loss function'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
